# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(-4.5,4.5,0.0001)
y= np.sqrt(1-(pow((abs(x)-1),2)))
y1= np.arccos(1-abs(x))-np.pi
y2 = np.sqrt(11-pow(x,2))
y3 = -np.sqrt(11-pow(x,2))
plt.figure("Geek code for lovers")
plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.xlabel("I Love You")
plt.ylabel("Forever")
plt.title("Geek code for lovers")
plt.show()
x=np.arange(-4.5,4.5,0.0001)
y=(np.sqrt(np.cos(x))*np.cos(300*x)+np.sqrt(abs(x))-0.7)*(pow((4-x*x),0.01))
y1= np.sqrt(4-(pow(x,2)))
y2= -np.sqrt(4-(pow(x,2)))
plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()
# Out:
# /var/folders/cf/7nzhdlvs5nl0_zh6ky9hz9vc0000gn/T/ipykernel_1523/2292023915.py:4: RuntimeWarning: invalid value encountered in sqrt
#   y= np.sqrt(1-(pow((abs(x)-1),2)))
# /var/folders/cf/7nzhdlvs5nl0_zh6ky9hz9vc0000gn/T/ipykernel_1523/2292023915.py:5: RuntimeWarning: invalid value encountered in arccos
#   y1= np.arccos(1-abs(x))-np.pi
# /var/folders/cf/7nzhdlvs5nl0_zh6ky9hz9vc0000gn/T/ipykernel_1523/2292023915.py:6: RuntimeWarning: invalid value encountered in sqrt
#   y2 = np.sqrt(11-pow(x,2))
# /var/folders/cf/7nzhdlvs5nl0_zh6ky9hz9vc0000gn/T/ipykernel_1523/2292023915.py:7: RuntimeWarning: invalid value encountered in sqrt
#   y3 = -np.sqrt(11-pow(x,2))
# /var/folders/cf/7nzhdlvs5nl0_zh6ky9hz9vc0000gn/T/ipykernel_1523/2292023915.py:18: RuntimeWarning: invalid value encountered in sqrt
#   y=(np.sqrt(np.cos(x))*np.cos(300*x)+np.sqrt(abs(x))-0.7)*(pow((4-x*x),0.01))
# /var/folders/cf/7nzhdlvs5nl0_zh6ky9hz9vc0000gn/T/ipykernel_1523/2292023915.py:18: RuntimeWarning: invalid value encountered in power
#   y=(np.sqrt(np.cos(x))*np.cos(300*x)+np.sqrt(abs(x))-0.7)*(pow((4-x*x),0.01))
# /var/folders/cf/7nzhdlvs5nl0_zh6ky9hz9vc0000gn/T/ipykernel_1523/2292023915.py:19: RuntimeWarning: invalid value encountered in sqrt
#   y1= np.sqrt(4-(pow(x,2)))
# /var/folders/cf/7nzhdlvs5nl0_zh6ky9hz9vc0000gn/T/ipykernel_1523/2292023915.py:20: RuntimeWarning: invalid value encountered in sqrt
#   y2= -np.sqrt(4-(pow(x,2)))
